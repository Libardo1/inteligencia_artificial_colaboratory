# %% [markdown]
# <a href="https://colab.research.google.com/github/mleyvaz/inteligencia_artificial_colaboratory/blob/master/Ficheros.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Crear un fichero de texto

# %%
with open('example.txt', 'w') as file:
  file.write('some context.\n')

# %% [markdown]
# ## Descargar Fichero

# %%
from google.colab import files
files.download('example.txt')

# %% [markdown]
# ## Subir  Fichero

# %%
uploaded=files.upload()
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-1f88d1d3-4107-470e-89f6-dc87437dbb61" name="files[]" multiple disabled />
#      <output id="result-1f88d1d3-4107-470e-89f6-dc87437dbb61">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 11173-Article Text-20701-1-10-20180420.pdf to 11173-Article Text-20701-1-10-20180420.pdf
# User uploaded file "11173-Article Text-20701-1-10-20180420.pdf" with length 4470520 bytes

# %% [markdown]
# Listado de ficheros  subidos

# %%
print(úploaded)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-6c2c32025eb3> in <module>()
# ----> 1 print(úploaded)
#
# NameError: name 'úploaded' is not defined

# %% [markdown]
# # CSV
#
# [Datos](https://github.com/mleyvaz/Data-science-python/blob/master/datasets/result.csv)

# %%
from google.colab import files
import pandas as pd

uploaded=files.upload()
# Out:
#      <input type="file" id="files-ecfc45e7-82cb-43e1-bcfe-64efdcbec571" name="files[]" multiple disabled />
#      <output id="result-ecfc45e7-82cb-43e1-bcfe-64efdcbec571">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving result.csv to result.csv

# %%
print(uploaded)
# Out:
# {'result.csv': b'link,permalink_url,created_time,type,id,shares/count,reactions/summary/total_count,reactions/summary/viewer_reaction,likes/summary/total_count,likes/summary/can_like,likes/summary/has_liked,comments/summary/order,comments/summary/total_count,comments/summary/can_comment,message,name\r\nhttps://www.facebook.com/MaikelLeyvaOficial/photos/a.1415268715235636.1073741828.1412883408807500/1663127900449715/?type=3,https://www.facebook.com/MaikelLeyvaOficial/posts/1663127937116378,2018-05-16T19:54:03+0000,photo,1412883408807500_1663127937116378,7,29,NONE,28,true,false,chronological,0,true,,\r\nhttps://www.facebook.com/MaikelLeyvaOficial/photos/a.1415268721902302.1073741829.1412883408807500/1657766324319206/?type=3,https://www.facebook.com/MaikelLeyvaOficial/posts/1657766324319206:0,2018-05-11T06:58:45+0000,photo,1412883408807500_1657766324319206,1,13,NONE,13,true,false,chronological,0,true,"Torneo en linea codefight en el curso de Python para data science. \r\n\r\n#codefights
# ...

# %%
with open('result.csv', 'r') as file:
  print (file.read())
  file.close()
# Out:
# link,permalink_url,created_time,type,id,shares/count,reactions/summary/total_count,reactions/summary/viewer_reaction,likes/summary/total_count,likes/summary/can_like,likes/summary/has_liked,comments/summary/order,comments/summary/total_count,comments/summary/can_comment,message,name
# https://www.facebook.com/MaikelLeyvaOficial/photos/a.1415268715235636.1073741828.1412883408807500/1663127900449715/?type=3,https://www.facebook.com/MaikelLeyvaOficial/posts/1663127937116378,2018-05-16T19:54:03+0000,photo,1412883408807500_1663127937116378,7,29,NONE,28,true,false,chronological,0,true,,
# https://www.facebook.com/MaikelLeyvaOficial/photos/a.1415268721902302.1073741829.1412883408807500/1657766324319206/?type=3,https://www.facebook.com/MaikelLeyvaOficial/posts/1657766324319206:0,2018-05-11T06:58:45+0000,photo,1412883408807500_1657766324319206,1,13,NONE,13,true,false,chronological,0,true,"Torneo en linea codefight en el curso de Python para data science.
#
# ...

# %% [markdown]
# ## importar en pandas

# %%
import io
from IPython.display import display, HTML
df=pd.read_csv(io.StringIO(uploaded['result.csv'].decode('utf8')))
display(df)
# Out:
#                                                  link  \
# 0   https://www.facebook.com/MaikelLeyvaOficial/ph...
# 1   https://www.facebook.com/MaikelLeyvaOficial/ph...
# 2   https://www.unocero.com/noticias/apps/jupyter-...
# 3   https://www.xataka.com/otros/mama-de-mayor-qui...
# 4   https://www.facebook.com/MaikelLeyvaOficial/ph...
# 5   https://www.facebook.com/MaikelLeyvaOficial/vi...
# 6   https://www.facebook.com/MaikelLeyvaOficial/vi...
# 7   https://www.facebook.com/MaikelLeyvaOficial/ph...
# 8   http://es.euronews.com/2018/05/02/la-union-eur...
# 9   https://www.facebook.com/MaikelLeyvaOficial/ph...
# 10  https://www.facebook.com/MaikelLeyvaOficial/vi...
# 11  https://www.facebook.com/MaikelLeyvaOficial/ph...
# 12  https://www.facebook.com/MaikelLeyvaOficial/ph...
# 13  https://www.facebook.com/MaikelLeyvaOficial/vi...
# 14  https://www.facebook.com/MaikelLeyvaOficial/ph...
# 15  https://www.facebook.com/MaikelLeyvaOficial/ph...
# ...

# %%
display(df.head(3))
# Out:
#                                                 link  \
# 0  https://www.facebook.com/MaikelLeyvaOficial/ph...
# 1  https://www.facebook.com/MaikelLeyvaOficial/ph...
# 2  https://www.unocero.com/noticias/apps/jupyter-...
#
#                                        permalink_url  \
# 0  https://www.facebook.com/MaikelLeyvaOficial/po...
# 1  https://www.facebook.com/MaikelLeyvaOficial/po...
# 2  https://www.facebook.com/MaikelLeyvaOficial/po...
#
#                created_time   type                                 id  \
# 0  2018-05-16T19:54:03+0000  photo  1412883408807500_1663127937116378
# 1  2018-05-11T06:58:45+0000  photo  1412883408807500_1657766324319206
# 2  2018-05-10T19:12:37+0000   link  1412883408807500_1657364924359346
#
#    shares/count  reactions/summary/total_count  \
# 0           7.0                             29
# 1           1.0                             13
# 2           1.0                              4
#
# ...
